# %%
from sklearn.datasets import fetch_mldata

# %%
import sklearn

import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#read it in
mnist = fetch_mldata("MNIST original")

# %%
#normalize it, split it up
X, y = mnist.data / 255., mnist.target
np.random.RandomState(7).shuffle(X)
np.random.RandomState(7).shuffle(y)
X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]

# %%
plt.imshow(X_train[0].reshape(28,28), cmap="gray")

plt.title("This is a %i"%int(y_train[0]))

# %%
# for scikit-learn algorithms we flatten it out

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train[:1000], y_train[:1000])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
model.score(X_test, y_test)
# Out:
# 0.88080000000000003

# %%
predictions = model.predict(X_test)

for i,prediction in enumerate(predictions[:10]):
    plt.figure(i)   
    plt.imshow(X_test[i].reshape(28,28), cmap="gray")
    plt.title(prediction)
